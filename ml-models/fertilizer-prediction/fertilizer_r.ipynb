# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fertilizer_r.csv')

# %%
df.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
unique_values = df['Soil Type'].unique()

# %%
unique_values
# Out:
# array(['Sandy', 'Loamy', 'Black', 'Red', 'Clayey'], dtype=object)

# %%
unique_values_crop_type = df['Crop Type'].unique()

# %%
unique_values_crop_type
# Out:
# array(['Maize', 'Sugarcane', 'Cotton', 'Tobacco', 'Paddy', 'Barley',
#        'Wheat', 'Millets', 'Oil seeds', 'Pulses', 'Ground Nuts'],
#       dtype=object)

# %%
unique_values_out = df['Fertilizer Name'].unique()

# %%
unique_values_out
# Out:
# array(['Urea', 'DAP', '14-35-14', '28-28', '17-17-17', '20-20',
#        '10-26-26'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
df1 = pd.read_csv('matchcropweight2.csv')
df1.head()
# Out:
#    crop type  weight
# 0      Maize       0
# 1  Sugarcane       1
# 2     Cotton       2
# 3    Tobacco       3
# 4      Paddy       4

# %%
cols = df.columns
data = df[cols].values.flatten()


vals = df.values
crop = df1['crop type'].unique()

for i in range(len(crop)):
    vals[vals == crop[i]] = df1[df1['crop type'] == crop[i]]['weight'].values[0]
    
d = pd.DataFrame(vals, columns=cols)
d.head()
# Out:
#   Temparature Humidity  Moisture Soil Type Crop Type Nitrogen Potassium  \
# 0          26        52       38     Sandy         0       37         0
# 1          29        52       45     Loamy         1       12         0
# 2          34        65       62     Black         2        7         9
# 3          32        62       34       Red         3       22         0
# 4          28        54       46    Clayey         4       35         0
#
#   Phosphorous Fertilizer Name
# 0           0            Urea
# 1          36             DAP
# 2          30        14-35-14
# 3          20           28-28
# 4           0            Urea

# %%
df2 = pd.read_csv('matchsoilweight.csv')
df2.head()
# Out:
#   Soil Type  weight
# 0     Sandy       0
# 1     Loamy       1
# 2     Black       2
# 3       Red       3
# 4    Clayey       4

# %%
d.head()
# Out:
#   Temparature Humidity  Moisture Soil Type Crop Type Nitrogen Potassium  \
# 0          26        52       38     Sandy         0       37         0
# 1          29        52       45     Loamy         1       12         0
# 2          34        65       62     Black         2        7         9
# 3          32        62       34       Red         3       22         0
# 4          28        54       46    Clayey         4       35         0
#
#   Phosphorous Fertilizer Name
# 0           0            Urea
# 1          36             DAP
# 2          30        14-35-14
# 3          20           28-28
# 4           0            Urea

# %%
cols = d.columns
data = d[cols].values.flatten()


vals = d.values
soil = df2['Soil Type'].unique()

for i in range(len(soil)):
    vals[vals == soil[i]] = df2[df2['Soil Type'] == soil[i]]['weight'].values[0]
    
d2 = pd.DataFrame(vals, columns=cols)
d2.head(30)
# Out:
#    Temparature Humidity  Moisture Soil Type Crop Type Nitrogen Potassium  \
# 0           26        52       38         0         0       37         0
# 1           29        52       45         1         1       12         0
# 2           34        65       62         2         2        7         9
# 3           32        62       34         3         3       22         0
# 4           28        54       46         4         4       35         0
# 5           26        52       35         0         5       12        10
# 6           25        50       64         3         2        9         0
# 7           33        64       50         1         6       41         0
# 8           30        60       42         0         7       21         0
# 9           29        58       33         2         8        9         7
# 10          27        54       28         4         9       13         0
# 11          31        62       48         0         0       14        15
# ...

# %%
d2 = d2.to_csv('finalfertilizerfilewithchanges.csv')

# %%
finaldf = pd.read_csv('finalfertilizerfilewithchanges.csv')

# %%
finaldf.head()
# Out:
#    Unnamed: 0  Temparature  Humidity   Moisture  Soil Type  Crop Type  \
# 0           0           26         52        38          0          0
# 1           1           29         52        45          1          1
# 2           2           34         65        62          2          2
# 3           3           32         62        34          3          3
# 4           4           28         54        46          4          4
#
#    Nitrogen  Potassium  Phosphorous Fertilizer Name
# 0        37          0            0            Urea
# 1        12          0           36             DAP
# 2         7          9           30        14-35-14
# 3        22          0           20           28-28
# 4        35          0            0            Urea

# %%
finaldf = finaldf.drop('Unnamed: 0', axis=1)

# %%
finaldf.head()
# Out:
#    Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0           26         52        38          0          0        37
# 1           29         52        45          1          1        12
# 2           34         65        62          2          2         7
# 3           32         62        34          3          3        22
# 4           28         54        46          4          4        35
#
#    Potassium  Phosphorous Fertilizer Name
# 0          0            0            Urea
# 1          0           36             DAP
# 2          9           30        14-35-14
# 3          0           20           28-28
# 4          0            0            Urea

# %%
finaldf.duplicated().sum()
# Out:
# 0

# %%
finaldf.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
finaldf.shape
# Out:
# (99, 9)

# %%
x = finaldf.loc[:,finaldf.columns!='Fertilizer Name']

# %%
x
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          0          0        37
# 1            29         52        45          1          1        12
# 2            34         65        62          2          2         7
# 3            32         62        34          3          3        22
# 4            28         54        46          4          4        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          4          9        24
# 95           30         60        27          3          3         4
# 96           38         72        51          1          6        39
# 97           36         60        43          0          7        15
# 98           29         58        57          2          1        12
#
#     Potassium  Phosphorous
# 0           0            0
# 1           0           36
# 2           9           30
# ...

# %%
y = finaldf.loc[:,finaldf.columns=='Fertilizer Name']

# %%
y
# Out:
#    Fertilizer Name
# 0             Urea
# 1              DAP
# 2         14-35-14
# 3            28-28
# 4             Urea
# ..             ...
# 94           28-28
# 95        10-26-26
# 96            Urea
# 97             DAP
# 98           20-20
#
# [99 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state = 0)

# %%
x_train
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 60           28         54        41          4          4        36
# 80           28         54        43          4          4        10
# 89           29         58        61          1          2        11
# 68           25         50        40          4          9         6
# 51           36         68        33          2          8        13
# ..          ...        ...       ...        ...        ...       ...
# 95           30         60        27          3          3         4
# 67           29         58        55          1          1         8
# 64           27         53        35          2          8        37
# 47           29         58        43          4          4        24
# 44           35         67        42          0          5        10
#
#     Potassium  Phosphorous
# 60          0            0
# 80          8           29
# 89          0           38
# ...

# %%
x_test
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 26           30         60        63          3          2         9
# 86           29         58        30          3          3        13
# 2            34         65        62          2          2         7
# 55           27         53        43          2          7        23
# 75           29         58        42          4          4         9
# 92           36         68        41          3         10        41
# 16           33         64        34          4          9        38
# 73           27         53        34          2          8        42
# 54           31         62        63          3          2        11
# 94           25         50        32          4          9        24
# 53           30         60        47          0          5        12
# 91           34         65        45          4          4         6
# 78           26         52        36          4          9         7
# ...

# %%
y_train
# Out:
#    Fertilizer Name
# 60            Urea
# 80        14-35-14
# 89             DAP
# 68        10-26-26
# 51           20-20
# ..             ...
# 95        10-26-26
# 67        14-35-14
# 64            Urea
# 47           28-28
# 44             DAP
#
# [69 rows x 1 columns]

# %%
y_test
# Out:
#    Fertilizer Name
# 26        14-35-14
# 86        10-26-26
# 2         14-35-14
# 55           28-28
# 75        14-35-14
# 92            Urea
# 16            Urea
# 73            Urea
# 54        17-17-17
# 94           28-28
# 53             DAP
# 91        10-26-26
# 78        10-26-26
# 13           28-28
# 7             Urea
# 30           28-28
# 22             DAP
# 24           20-20
# 33        14-35-14
# 8            28-28
# 43            Urea
# 62           28-28
# 3            28-28
# 71            Urea
# 45        14-35-14
# 48            Urea
# 6            20-20
# 98           20-20
# 82             DAP
# 76           28-28

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# C:\Users\ASUS\anancondanew\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ASUS\anancondanew\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred= model.predict(x_test)

# %%
y_pred
# Out:
# array(['14-35-14', '17-17-17', '14-35-14', '28-28', '14-35-14', 'Urea',
#        'Urea', 'Urea', '17-17-17', '28-28', 'DAP', '10-26-26', '10-26-26',
#        '28-28', 'Urea', '28-28', 'DAP', '20-20', '14-35-14', '28-28',
#        'Urea', '28-28', '28-28', 'Urea', '14-35-14', 'Urea', '20-20',
#        '20-20', 'DAP', '28-28'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9666666666666667

# %%
import pickle
filename = 'fertilizer_r_final.pkl'
pickle.dump(model,open(filename,'wb'))
